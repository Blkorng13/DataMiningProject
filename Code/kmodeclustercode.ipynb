# %%
# !pip install kmodes
# Out:
# Collecting kmodes
#   Downloading kmodes-0.12.2-py2.py3-none-any.whl.metadata (8.1 kB)
# Requirement already satisfied: numpy>=1.10.4 in c:\users\rocke\appdata\local\programs\python\python313\lib\site-packages (from kmodes) (2.2.1)
# Requirement already satisfied: scikit-learn>=0.22.0 in c:\users\rocke\appdata\local\programs\python\python313\lib\site-packages (from kmodes) (1.6.1)
# Requirement already satisfied: scipy>=0.13.3 in c:\users\rocke\appdata\local\programs\python\python313\lib\site-packages (from kmodes) (1.15.1)
# Requirement already satisfied: joblib>=0.11 in c:\users\rocke\appdata\local\programs\python\python313\lib\site-packages (from kmodes) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\rocke\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn>=0.22.0->kmodes) (3.6.0)
# Downloading kmodes-0.12.2-py2.py3-none-any.whl (20 kB)
# Installing collected packages: kmodes
# Successfully installed kmodes-0.12.2
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt
from kmodes.kmodes import KModes
import pandas as pd
#Load the compact dataset
df = pd.read_parquet("mushroom_compact.parquet", engine="fastparquet")

cols_to_drop = [
    "cap-surface",
    "gill-attachment",
    "gill-spacing",
    "stem-root",
    "stem-surface",
    "veil-type",
    "veil-color",
    "spore-print-color",]
df_model = df.drop(columns=cols_to_drop).copy()

#remove numeric features for chi-square
df_km = df_model.drop(columns=["cap-diameter", "stem-height", "stem-width"])

# %%
#convert everything to string and fill NaNs
df_km = df_km.astype(str).fillna("missing")

# %%
#sample for workable dataset

df_km_sample = df_km.sample(n=50000, random_state=42)

df_km_sample.head()
# Out:
#         class cap-shape cap-color does-bruise-or-bleed gill-color stem-color  \
# 6582897     p         c         w                    t          p          w
# 603267      p         f         n                    f          n          n
# 4700054     p         f         o                    f          o          o
# 6581571     p         x         n                    f          n          n
# 2746629     p         x         g                    t          u          g
#
#         has-ring ring-type habitat season
# 6582897        f         f       g      s
# 603267         t         f       d      u
# 4700054        f         f       g      u
# 6581571        f         f       h      a
# 2746629        f         f       d      a

# %%
#find the best k
costs = []
K = range(2, 10)

for k in K:
    km = KModes(n_clusters=k, init="Huang", n_init=3, verbose=0)
    clusters = km.fit_predict(df_km_sample)
    costs.append(km.cost_)

costs
# Out:
# [np.float64(189919.0),
#  np.float64(181075.0),
#  np.float64(175312.0),
#  np.float64(164119.0),
#  np.float64(163873.0),
#  np.float64(156483.0),
#  np.float64(158787.0),
#  np.float64(150471.0)]

# %%
#plot to choose
plt.plot(K, costs, marker="o")
plt.xlabel("k (number of clusters)")
plt.ylabel("Cost")
plt.title("K-Modes Cost vs k")
plt.show()

# %%
#choosing k=5 fit the kmodes model
km_final = KModes(n_clusters=4, init="Huang", n_init=5, verbose=1)
clusters = km_final.fit_predict(df_km_sample)
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 2780, cost: 180127.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 17249, cost: 178088.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 15095, cost: 178009.0
# Run 3, iteration: 2/100, moves: 905, cost: 178009.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 16329, cost: 174706.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 17344, cost: 183124.0
# Run 5, iteration: 2/100, moves: 5041, cost: 183124.0
# Best run was number 4

# %%
#look at centroids
centroids = pd.DataFrame(km_final.cluster_centroids_, columns=df_km_sample.columns)
centroids
# Out:
#   class cap-shape cap-color does-bruise-or-bleed gill-color stem-color  \
# 0     e         x         n                    f          w          n
# 1     e         f         w                    f          w          w
# 2     p         x         n                    f          y          w
# 3     p         x         n                    f          n          n
#
#   has-ring ring-type habitat season
# 0        f         f       d      a
# 1        f         f       d      a
# 2        f         f       d      a
# 3        t         f       d      u

# %%
#cluster labels
df_km_sample["cluster"] = clusters
df_km_sample.head()
# Out:
#         class cap-shape cap-color does-bruise-or-bleed gill-color stem-color  \
# 6582897     p         c         w                    t          p          w
# 603267      p         f         n                    f          n          n
# 4700054     p         f         o                    f          o          o
# 6581571     p         x         n                    f          n          n
# 2746629     p         x         g                    t          u          g
#
#         has-ring ring-type habitat season  cluster
# 6582897        f         f       g      s        1
# 603267         t         f       d      u        3
# 4700054        f         f       g      u        1
# 6581571        f         f       h      a        0
# 2746629        f         f       d      a        2

# %%
#class distribution
df_km_sample.groupby("cluster")["class"].value_counts(normalize=True)
# Out:
# cluster  class
# 0        e        0.761328
#          p        0.238672
# 1        e        0.599465
#          p        0.400535
# 2        p        0.958450
#          e        0.041550
# 3        p        0.880530
#          e        0.119470
# Name: proportion, dtype: float64
